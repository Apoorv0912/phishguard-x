# %%
from pathlib import Path
import sys

import pandas as pd

# Add project root to Python path
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.data.loader import (
    load_phishing_data,
    load_legitimate_data,
    sample_phishing_urls,
    sample_legitimate_urls,
)

# %%
import requests
from pathlib import Path

url = "http://data.phishtank.com/data/online-valid.csv"

output_path = Path("../data/raw/online-valid.csv")

response = requests.get(url, timeout=30)

response.raise_for_status()

output_path.parent.mkdir(parents=True, exist_ok=True)

with open(output_path, "wb") as f:
    f.write(response.content)

print(f"Downloaded successfully: {output_path}")

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
PHISHING_DATA_PATH = PROJECT_ROOT / "data" / "raw" / "2.online-valid.csv"
LEGITIMATE_DATA_PATH = PROJECT_ROOT / "data" / "raw" / "1.Benign_list_big_final.csv"

print(f"Phishing dataset : {PHISHING_DATA_PATH}")
print(f"Legitimate dataset : {LEGITIMATE_DATA_PATH}")
# Out:
# Phishing dataset : c:\Users\nk134\OneDrive\Desktop\coding\phishguard-x\data\raw\2.online-valid.csv
# Legitimate dataset : c:\Users\nk134\OneDrive\Desktop\coding\phishguard-x\data\raw\1.Benign_list_big_final.csv

# %%
# Loading the phishing URLs dataset

data0 = load_phishing_data(PHISHING_DATA_PATH)

data0.head()
# Out:
#    phish_id                                              url  \
# 0   9521570       https://centrala-administracja.vercel.app/
# 1   9521566  https://mawnowvasnanz-dpleh6oql3aj.edgeone.dev/
# 2   9521565                 https://login-outlook365.yzz.me/
# 3   9521564             https://login-outlook365.yzz.me/?i=1
# 4   9521563       https://fb-meta-verified-14259.vercel.app/
#
#                                     phish_detail_url  \
# 0  http://www.phishtank.com/phish_detail.php?phis...
# 1  http://www.phishtank.com/phish_detail.php?phis...
# 2  http://www.phishtank.com/phish_detail.php?phis...
# 3  http://www.phishtank.com/phish_detail.php?phis...
# 4  http://www.phishtank.com/phish_detail.php?phis...
#
#              submission_time verified          verification_time online  \
# 0  2026-09-09T18:17:37+00:00      yes  2026-09-09T18:21:54+00:00    yes
# 1  2026-09-09T18:10:46+00:00      yes  2026-09-09T18:21:54+00:00    yes
# ...

# %%
data0.shape
# Out:
# (75472, 8)

# %%
phishurl = data0.sample(n = 5000, random_state = 12).copy()
phishurl = phishurl.reset_index(drop=True)
phishurl.head()
# Out:
#    phish_id                                             url  \
# 0   9475335            https://chrtrer09765.framer.website/
# 1   9491283  https://full-transportation-630661.framer.app/
# 2   7560847       https://domappcheckomeg7.firebaseapp.com/
# 3   9400443               https://belproxskyfqa.weebly.com/
# 4   9437465              https://www.gov-parkingqs.cyou/com
#
#                                     phish_detail_url  \
# 0  http://www.phishtank.com/phish_detail.php?phis...
# 1  http://www.phishtank.com/phish_detail.php?phis...
# 2  http://www.phishtank.com/phish_detail.php?phis...
# 3  http://www.phishtank.com/phish_detail.php?phis...
# 4  http://www.phishtank.com/phish_detail.php?phis...
#
#              submission_time verified          verification_time online target
# 0  2026-07-11T18:27:29+00:00      yes  2026-07-11T18:52:38+00:00    yes  Other
# 1  2026-07-30T13:57:34+00:00      yes  2026-07-30T14:03:21+00:00    yes  Other
# ...

# %%
phishurl.shape
# Out:
# (5000, 8)

# %%
data1 = pd.read_csv(LEGITIMATE_DATA_PATH)
data1.columns = ['URLs']
data1.head()
# Out:
#                                                 URLs
# 0  http://1337x.to/torrent/1110018/Blackhat-2015-...
# 1  http://1337x.to/torrent/1122940/Blackhat-2015-...
# 2  http://1337x.to/torrent/1124395/Fast-and-Furio...
# 3  http://1337x.to/torrent/1145504/Avengers-Age-o...
# 4  http://1337x.to/torrent/1160078/Avengers-age-o...

# %%
legiurl = data1.sample(n = 5000, random_state = 12).copy()
legiurl = legiurl.reset_index(drop=True)
legiurl.head()
# Out:
#                                                 URLs
# 0  http://graphicriver.net/search?date=this-month...
# 1  http://ecnavi.jp/redirect/?url=http://www.cros...
# 2  https://hubpages.com/signin?explain=follow+Hub...
# 3  http://extratorrent.cc/torrent/4190536/AOMEI+B...
# 4  http://icicibank.com/Personal-Banking/offers/o...

# %%
legiurl.shape
# Out:
# (5000, 1)
